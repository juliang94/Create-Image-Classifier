# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
#### Imports here
import torch
from torch import nn, optim
import torch.nn.functional as F
from torchvision import datasets, transforms, models

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
## data directories
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

## means and standard deviations for the normalizations
means = [0.485, 0.456, 0.406]
stds = [0.229, 0.224, 0.225]

## training and validation: apply random scaling (224), cropping, and flipping
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                      transforms.CenterCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize(means, stds)])

## testing: apply resize and crop to 224
test_transforms = transforms.Compose([transforms.RandomResizedCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize(means, stds)])

val_transforms = transforms.Compose([transforms.RandomResizedCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize(means, stds)])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir, transform= train_transforms)
test_data = datasets.ImageFolder(test_dir, transform= test_transforms)
val_data = datasets.ImageFolder(valid_dir, transform = val_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data, batch_size= 64, shuffle = True)
testloader = torch.utils.data.DataLoader(test_data, batch_size= 64)
valloader = torch.utils.data.DataLoader(val_data, batch_size= 64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

## define model
model = models.densenet121(pretrained= True)
model
# Out:
# /opt/conda/lib/python3.6/site-packages/torchvision-0.2.1-py3.6.egg/torchvision/models/densenet.py:212: UserWarning: nn.init.kaiming_normal is now deprecated in favor of nn.init.kaiming_normal_.
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.torch/models/densenet121-a639ec97.pth
# 100%|██████████| 32342954/32342954 [00:00<00:00, 48733430.88it/s]
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
## use 1024 inputs, 1000 outputs according to (fc) line in the model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
## freeze paramerters
for param in model.parameters():
    param.requires_grad = True

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()
print(type(images))
print(images.shape)
print(labels.shape)
# Out:
# <class 'torch.Tensor'>
# torch.Size([64, 3, 224, 224])
# torch.Size([64])

# %%
## build classifier
classifier = nn.Sequential(nn.Linear(1024, 500),
                           nn.ReLU(),
                           nn.Dropout(p = 0.3),
                           nn.Linear(500, 102),
                           nn.LogSoftmax(dim = 1))
model.classifier = classifier
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=1024, out_features=500, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.3)
#   (3): Linear(in_features=500, out_features=102, bias=True)
#   (4): LogSoftmax()
# )

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr = 0.001)

model.to(device);

# %%
## train model

epochs = 18
steps = 0
running_loss = 0
print_every = 5

for e in range(epochs):
    for images, labels in trainloader:
        steps += 1
        
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        log_ps = model.forward(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            val_loss = 0 ## validation loss
            accuracy = 0
            model.eval()

            with torch.no_grad():
                for images, labels in valloader:
                    images, labels = images.to(device), labels.to(device)

                    log_ps = model.forward(images)
                    loss = criterion(log_ps, labels)

                    val_loss += loss.item()

                    ## calculate accuracy
                    ps = torch.exp(log_ps)
                    top_p, top_class = ps.topk(1, dim = 1)
                    equals = (top_class == labels.view(*top_class.shape))

                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    #print(val_loss)
 
            print(f"Epoch: {e+1}/{epochs}.."
                  f"Train loss: {running_loss/print_every:.3f}.. "
                  f"Validation loss: {val_loss/len(valloader):.3f}.. "
                  f"Accuracy: {accuracy/len(valloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# Epoch: 1/18..Train loss: 4.558.. Validation loss: 4.511.. Accuracy: 0.042
# Epoch: 1/18..Train loss: 4.463.. Validation loss: 4.455.. Accuracy: 0.050
# Epoch: 1/18..Train loss: 4.430.. Validation loss: 4.362.. Accuracy: 0.099
# Epoch: 1/18..Train loss: 4.334.. Validation loss: 4.251.. Accuracy: 0.190
# Epoch: 1/18..Train loss: 4.088.. Validation loss: 4.111.. Accuracy: 0.138
# Epoch: 1/18..Train loss: 3.987.. Validation loss: 4.009.. Accuracy: 0.166
# Epoch: 1/18..Train loss: 3.666.. Validation loss: 3.920.. Accuracy: 0.184
# Epoch: 1/18..Train loss: 3.670.. Validation loss: 3.744.. Accuracy: 0.232
# Epoch: 1/18..Train loss: 3.411.. Validation loss: 3.685.. Accuracy: 0.212
# Epoch: 1/18..Train loss: 3.244.. Validation loss: 3.531.. Accuracy: 0.246
# Epoch: 1/18..Train loss: 3.122.. Validation loss: 3.455.. Accuracy: 0.262
# Epoch: 1/18..Train loss: 2.988.. Validation loss: 3.264.. Accuracy: 0.297
# Epoch: 1/18..Train loss: 2.884.. Validation loss: 3.200.. Accuracy: 0.331
# Epoch: 1/18..Train loss: 2.692.. Validation loss: 3.061.. Accuracy: 0.337
# Epoch: 1/18..Train loss: 2.464.. Validation loss: 2.960.. Accuracy: 0.353
# Epoch: 1/18..Train loss: 2.456.. Validation loss: 2.816.. Accuracy: 0.385
# Epoch: 1/18..Train loss: 2.417.. Validation loss: 2.810.. Accuracy: 0.354
# Epoch: 1/18..Train loss: 2.222.. Validation loss: 2.671.. Accuracy: 0.412
# Epoch: 1/18..Train loss: 2.064.. Validation loss: 2.557.. Accuracy: 0.453
# Epoch: 1/18..Train loss: 1.946.. Validation loss: 2.522.. Accuracy: 0.401
# Epoch: 2/18..Train loss: 1.949.. Validation loss: 2.513.. Accuracy: 0.426
# Epoch: 2/18..Train loss: 1.814.. Validation loss: 2.376.. Accuracy: 0.464
# Epoch: 2/18..Train loss: 1.764.. Validation loss: 2.289.. Accuracy: 0.474
# Epoch: 2/18..Train loss: 1.733.. Validation loss: 2.297.. Accuracy: 0.468
# Epoch: 2/18..Train loss: 1.629.. Validation loss: 2.189.. Accuracy: 0.486
# Epoch: 2/18..Train loss: 1.588.. Validation loss: 2.185.. Accuracy: 0.502
# Epoch: 2/18..Train loss: 1.436.. Validation loss: 2.298.. Accuracy: 0.449
# Epoch: 2/18..Train loss: 1.447.. Validation loss: 2.240.. Accuracy: 0.447
# Epoch: 2/18..Train loss: 1.447.. Validation loss: 2.041.. Accuracy: 0.486
# Epoch: 2/18..Train loss: 1.399.. Validation loss: 1.932.. Accuracy: 0.565
# Epoch: 2/18..Train loss: 1.531.. Validation loss: 2.077.. Accuracy: 0.503
# Epoch: 2/18..Train loss: 1.308.. Validation loss: 2.017.. Accuracy: 0.489
# Epoch: 2/18..Train loss: 1.213.. Validation loss: 1.987.. Accuracy: 0.502
# Epoch: 2/18..Train loss: 1.183.. Validation loss: 1.936.. Accuracy: 0.539
# Epoch: 2/18..Train loss: 1.220.. Validation loss: 1.866.. Accuracy: 0.561
# Epoch: 2/18..Train loss: 1.299.. Validation loss: 1.887.. Accuracy: 0.521
# Epoch: 2/18..Train loss: 1.207.. Validation loss: 1.787.. Accuracy: 0.551
# Epoch: 2/18..Train loss: 1.205.. Validation loss: 1.769.. Accuracy: 0.535
# Epoch: 2/18..Train loss: 1.256.. Validation loss: 1.946.. Accuracy: 0.507
# Epoch: 2/18..Train loss: 1.114.. Validation loss: 1.823.. Accuracy: 0.549
# Epoch: 2/18..Train loss: 1.142.. Validation loss: 1.913.. Accuracy: 0.514
# Epoch: 3/18..Train loss: 1.133.. Validation loss: 1.816.. Accuracy: 0.554
# Epoch: 3/18..Train loss: 1.147.. Validation loss: 1.655.. Accuracy: 0.575
# Epoch: 3/18..Train loss: 1.086.. Validation loss: 1.608.. Accuracy: 0.628
# Epoch: 3/18..Train loss: 1.050.. Validation loss: 1.663.. Accuracy: 0.575
# Epoch: 3/18..Train loss: 0.885.. Validation loss: 1.745.. Accuracy: 0.555
# Epoch: 3/18..Train loss: 0.932.. Validation loss: 1.756.. Accuracy: 0.555
# Epoch: 3/18..Train loss: 0.882.. Validation loss: 1.679.. Accuracy: 0.589
# Epoch: 3/18..Train loss: 0.954.. Validation loss: 1.656.. Accuracy: 0.585
# Epoch: 3/18..Train loss: 1.043.. Validation loss: 1.610.. Accuracy: 0.593
# Epoch: 3/18..Train loss: 0.971.. Validation loss: 1.633.. Accuracy: 0.592
# Epoch: 3/18..Train loss: 0.950.. Validation loss: 1.637.. Accuracy: 0.565
# Epoch: 3/18..Train loss: 0.956.. Validation loss: 1.723.. Accuracy: 0.549
# Epoch: 3/18..Train loss: 0.898.. Validation loss: 1.701.. Accuracy: 0.572
# Epoch: 3/18..Train loss: 0.804.. Validation loss: 1.644.. Accuracy: 0.581
# Epoch: 3/18..Train loss: 0.965.. Validation loss: 1.583.. Accuracy: 0.599
# Epoch: 3/18..Train loss: 0.939.. Validation loss: 1.520.. Accuracy: 0.609
# Epoch: 3/18..Train loss: 0.889.. Validation loss: 1.563.. Accuracy: 0.587
# Epoch: 3/18..Train loss: 0.842.. Validation loss: 1.600.. Accuracy: 0.591
# Epoch: 3/18..Train loss: 0.959.. Validation loss: 1.539.. Accuracy: 0.625
# Epoch: 3/18..Train loss: 0.942.. Validation loss: 1.543.. Accuracy: 0.595
# Epoch: 4/18..Train loss: 0.818.. Validation loss: 1.614.. Accuracy: 0.596
# Epoch: 4/18..Train loss: 0.787.. Validation loss: 1.600.. Accuracy: 0.574
# Epoch: 4/18..Train loss: 0.853.. Validation loss: 1.499.. Accuracy: 0.614
# Epoch: 4/18..Train loss: 0.764.. Validation loss: 1.454.. Accuracy: 0.619
# Epoch: 4/18..Train loss: 0.780.. Validation loss: 1.446.. Accuracy: 0.641
# Epoch: 4/18..Train loss: 0.716.. Validation loss: 1.684.. Accuracy: 0.559
# Epoch: 4/18..Train loss: 0.843.. Validation loss: 1.570.. Accuracy: 0.572
# Epoch: 4/18..Train loss: 0.766.. Validation loss: 1.499.. Accuracy: 0.618
# Epoch: 4/18..Train loss: 0.708.. Validation loss: 1.453.. Accuracy: 0.616
# Epoch: 4/18..Train loss: 0.750.. Validation loss: 1.461.. Accuracy: 0.628
# Epoch: 4/18..Train loss: 0.658.. Validation loss: 1.455.. Accuracy: 0.612
# Epoch: 4/18..Train loss: 0.696.. Validation loss: 1.557.. Accuracy: 0.600
# Epoch: 4/18..Train loss: 0.659.. Validation loss: 1.544.. Accuracy: 0.592
# Epoch: 4/18..Train loss: 0.626.. Validation loss: 1.418.. Accuracy: 0.640
# Epoch: 4/18..Train loss: 0.669.. Validation loss: 1.460.. Accuracy: 0.605
# Epoch: 4/18..Train loss: 0.639.. Validation loss: 1.359.. Accuracy: 0.646
# Epoch: 4/18..Train loss: 0.773.. Validation loss: 1.398.. Accuracy: 0.626
# Epoch: 4/18..Train loss: 0.718.. Validation loss: 1.476.. Accuracy: 0.593
# Epoch: 4/18..Train loss: 0.674.. Validation loss: 1.482.. Accuracy: 0.616
# Epoch: 4/18..Train loss: 0.726.. Validation loss: 1.366.. Accuracy: 0.654
# Epoch: 4/18..Train loss: 0.645.. Validation loss: 1.322.. Accuracy: 0.643
# Epoch: 5/18..Train loss: 0.633.. Validation loss: 1.435.. Accuracy: 0.599
# Epoch: 5/18..Train loss: 0.683.. Validation loss: 1.466.. Accuracy: 0.628
# Epoch: 5/18..Train loss: 0.518.. Validation loss: 1.333.. Accuracy: 0.665
# Epoch: 5/18..Train loss: 0.587.. Validation loss: 1.390.. Accuracy: 0.636
# Epoch: 5/18..Train loss: 0.613.. Validation loss: 1.410.. Accuracy: 0.618
# Epoch: 5/18..Train loss: 0.552.. Validation loss: 1.404.. Accuracy: 0.615
# Epoch: 5/18..Train loss: 0.569.. Validation loss: 1.400.. Accuracy: 0.619
# Epoch: 5/18..Train loss: 0.610.. Validation loss: 1.467.. Accuracy: 0.612
# Epoch: 5/18..Train loss: 0.711.. Validation loss: 1.468.. Accuracy: 0.626
# Epoch: 5/18..Train loss: 0.523.. Validation loss: 1.498.. Accuracy: 0.612
# Epoch: 5/18..Train loss: 0.535.. Validation loss: 1.336.. Accuracy: 0.652
# Epoch: 5/18..Train loss: 0.659.. Validation loss: 1.356.. Accuracy: 0.643
# Epoch: 5/18..Train loss: 0.607.. Validation loss: 1.331.. Accuracy: 0.652
# Epoch: 5/18..Train loss: 0.601.. Validation loss: 1.215.. Accuracy: 0.674
# Epoch: 5/18..Train loss: 0.532.. Validation loss: 1.311.. Accuracy: 0.652
# Epoch: 5/18..Train loss: 0.673.. Validation loss: 1.430.. Accuracy: 0.602
# Epoch: 5/18..Train loss: 0.617.. Validation loss: 1.397.. Accuracy: 0.635
# Epoch: 5/18..Train loss: 0.565.. Validation loss: 1.418.. Accuracy: 0.629
# Epoch: 5/18..Train loss: 0.646.. Validation loss: 1.300.. Accuracy: 0.658
# Epoch: 5/18..Train loss: 0.686.. Validation loss: 1.425.. Accuracy: 0.642
# Epoch: 5/18..Train loss: 0.603.. Validation loss: 1.228.. Accuracy: 0.666
# Epoch: 6/18..Train loss: 0.554.. Validation loss: 1.313.. Accuracy: 0.659
# Epoch: 6/18..Train loss: 0.587.. Validation loss: 1.331.. Accuracy: 0.641
# Epoch: 6/18..Train loss: 0.571.. Validation loss: 1.385.. Accuracy: 0.644
# Epoch: 6/18..Train loss: 0.480.. Validation loss: 1.245.. Accuracy: 0.674
# Epoch: 6/18..Train loss: 0.446.. Validation loss: 1.281.. Accuracy: 0.672
# Epoch: 6/18..Train loss: 0.613.. Validation loss: 1.330.. Accuracy: 0.650
# Epoch: 6/18..Train loss: 0.506.. Validation loss: 1.369.. Accuracy: 0.635
# Epoch: 6/18..Train loss: 0.485.. Validation loss: 1.318.. Accuracy: 0.629
# Epoch: 6/18..Train loss: 0.569.. Validation loss: 1.356.. Accuracy: 0.634
# Epoch: 6/18..Train loss: 0.560.. Validation loss: 1.271.. Accuracy: 0.646
# Epoch: 6/18..Train loss: 0.591.. Validation loss: 1.299.. Accuracy: 0.644
# Epoch: 6/18..Train loss: 0.561.. Validation loss: 1.441.. Accuracy: 0.622
# Epoch: 6/18..Train loss: 0.471.. Validation loss: 1.327.. Accuracy: 0.660
# Epoch: 6/18..Train loss: 0.576.. Validation loss: 1.405.. Accuracy: 0.651
# Epoch: 6/18..Train loss: 0.570.. Validation loss: 1.250.. Accuracy: 0.664
# Epoch: 6/18..Train loss: 0.585.. Validation loss: 1.245.. Accuracy: 0.659
# Epoch: 6/18..Train loss: 0.558.. Validation loss: 1.241.. Accuracy: 0.669
# Epoch: 6/18..Train loss: 0.509.. Validation loss: 1.302.. Accuracy: 0.674
# Epoch: 6/18..Train loss: 0.461.. Validation loss: 1.366.. Accuracy: 0.635
# Epoch: 6/18..Train loss: 0.556.. Validation loss: 1.337.. Accuracy: 0.639
# Epoch: 7/18..Train loss: 0.552.. Validation loss: 1.271.. Accuracy: 0.669
# Epoch: 7/18..Train loss: 0.468.. Validation loss: 1.259.. Accuracy: 0.665
# Epoch: 7/18..Train loss: 0.516.. Validation loss: 1.328.. Accuracy: 0.657
# Epoch: 7/18..Train loss: 0.461.. Validation loss: 1.287.. Accuracy: 0.661
# Epoch: 7/18..Train loss: 0.355.. Validation loss: 1.389.. Accuracy: 0.629
# Epoch: 7/18..Train loss: 0.548.. Validation loss: 1.359.. Accuracy: 0.629
# Epoch: 7/18..Train loss: 0.524.. Validation loss: 1.261.. Accuracy: 0.673
# Epoch: 7/18..Train loss: 0.551.. Validation loss: 1.174.. Accuracy: 0.680
# Epoch: 7/18..Train loss: 0.433.. Validation loss: 1.322.. Accuracy: 0.669
# Epoch: 7/18..Train loss: 0.516.. Validation loss: 1.325.. Accuracy: 0.658
# Epoch: 7/18..Train loss: 0.400.. Validation loss: 1.316.. Accuracy: 0.653
# Epoch: 7/18..Train loss: 0.453.. Validation loss: 1.311.. Accuracy: 0.642
# Epoch: 7/18..Train loss: 0.457.. Validation loss: 1.208.. Accuracy: 0.670
# Epoch: 7/18..Train loss: 0.537.. Validation loss: 1.220.. Accuracy: 0.668
# Epoch: 7/18..Train loss: 0.461.. Validation loss: 1.196.. Accuracy: 0.668
# Epoch: 7/18..Train loss: 0.448.. Validation loss: 1.239.. Accuracy: 0.658
# Epoch: 7/18..Train loss: 0.452.. Validation loss: 1.289.. Accuracy: 0.655
# Epoch: 7/18..Train loss: 0.414.. Validation loss: 1.200.. Accuracy: 0.683
# Epoch: 7/18..Train loss: 0.449.. Validation loss: 1.215.. Accuracy: 0.672
# Epoch: 7/18..Train loss: 0.586.. Validation loss: 1.224.. Accuracy: 0.649
# Epoch: 7/18..Train loss: 0.493.. Validation loss: 1.305.. Accuracy: 0.662
# Epoch: 8/18..Train loss: 0.528.. Validation loss: 1.308.. Accuracy: 0.661
# Epoch: 8/18..Train loss: 0.433.. Validation loss: 1.247.. Accuracy: 0.689
# Epoch: 8/18..Train loss: 0.325.. Validation loss: 1.266.. Accuracy: 0.671
# Epoch: 8/18..Train loss: 0.466.. Validation loss: 1.359.. Accuracy: 0.623
# Epoch: 8/18..Train loss: 0.545.. Validation loss: 1.355.. Accuracy: 0.644
# Epoch: 8/18..Train loss: 0.502.. Validation loss: 1.268.. Accuracy: 0.664
# Epoch: 8/18..Train loss: 0.378.. Validation loss: 1.175.. Accuracy: 0.682
# Epoch: 8/18..Train loss: 0.363.. Validation loss: 1.292.. Accuracy: 0.647
# Epoch: 8/18..Train loss: 0.377.. Validation loss: 1.241.. Accuracy: 0.659
# Epoch: 8/18..Train loss: 0.480.. Validation loss: 1.146.. Accuracy: 0.689
# Epoch: 8/18..Train loss: 0.430.. Validation loss: 1.209.. Accuracy: 0.677
# Epoch: 8/18..Train loss: 0.458.. Validation loss: 1.264.. Accuracy: 0.663
# Epoch: 8/18..Train loss: 0.430.. Validation loss: 1.175.. Accuracy: 0.691
# Epoch: 8/18..Train loss: 0.439.. Validation loss: 1.220.. Accuracy: 0.688
# Epoch: 8/18..Train loss: 0.533.. Validation loss: 1.195.. Accuracy: 0.687
# Epoch: 8/18..Train loss: 0.467.. Validation loss: 1.147.. Accuracy: 0.707
# Epoch: 8/18..Train loss: 0.363.. Validation loss: 1.242.. Accuracy: 0.661
# Epoch: 8/18..Train loss: 0.353.. Validation loss: 1.239.. Accuracy: 0.670
# Epoch: 8/18..Train loss: 0.431.. Validation loss: 1.273.. Accuracy: 0.659
# Epoch: 8/18..Train loss: 0.436.. Validation loss: 1.281.. Accuracy: 0.650
# Epoch: 9/18..Train loss: 0.427.. Validation loss: 1.277.. Accuracy: 0.663
# Epoch: 9/18..Train loss: 0.380.. Validation loss: 1.303.. Accuracy: 0.659
# Epoch: 9/18..Train loss: 0.415.. Validation loss: 1.242.. Accuracy: 0.673
# Epoch: 9/18..Train loss: 0.337.. Validation loss: 1.167.. Accuracy: 0.693
# Epoch: 9/18..Train loss: 0.374.. Validation loss: 1.094.. Accuracy: 0.697
# Epoch: 9/18..Train loss: 0.409.. Validation loss: 1.124.. Accuracy: 0.693
# Epoch: 9/18..Train loss: 0.419.. Validation loss: 1.285.. Accuracy: 0.675
# Epoch: 9/18..Train loss: 0.405.. Validation loss: 1.359.. Accuracy: 0.643
# Epoch: 9/18..Train loss: 0.302.. Validation loss: 1.321.. Accuracy: 0.659
# Epoch: 9/18..Train loss: 0.325.. Validation loss: 1.169.. Accuracy: 0.690
# Epoch: 9/18..Train loss: 0.454.. Validation loss: 1.075.. Accuracy: 0.704
# Epoch: 9/18..Train loss: 0.487.. Validation loss: 1.199.. Accuracy: 0.686
# Epoch: 9/18..Train loss: 0.440.. Validation loss: 1.270.. Accuracy: 0.670
# Epoch: 9/18..Train loss: 0.338.. Validation loss: 1.230.. Accuracy: 0.669
# Epoch: 9/18..Train loss: 0.420.. Validation loss: 1.175.. Accuracy: 0.690
# Epoch: 9/18..Train loss: 0.385.. Validation loss: 1.281.. Accuracy: 0.659
# Epoch: 9/18..Train loss: 0.421.. Validation loss: 1.254.. Accuracy: 0.687
# Epoch: 9/18..Train loss: 0.353.. Validation loss: 1.220.. Accuracy: 0.656
# Epoch: 9/18..Train loss: 0.311.. Validation loss: 1.166.. Accuracy: 0.669
# Epoch: 9/18..Train loss: 0.481.. Validation loss: 1.175.. Accuracy: 0.695
# Epoch: 9/18..Train loss: 0.411.. Validation loss: 1.118.. Accuracy: 0.694
# Epoch: 10/18..Train loss: 0.421.. Validation loss: 1.133.. Accuracy: 0.697
# Epoch: 10/18..Train loss: 0.319.. Validation loss: 1.148.. Accuracy: 0.697
# Epoch: 10/18..Train loss: 0.415.. Validation loss: 1.174.. Accuracy: 0.688
# Epoch: 10/18..Train loss: 0.354.. Validation loss: 1.053.. Accuracy: 0.717
# Epoch: 10/18..Train loss: 0.375.. Validation loss: 1.103.. Accuracy: 0.710
# Epoch: 10/18..Train loss: 0.375.. Validation loss: 1.111.. Accuracy: 0.712
# Epoch: 10/18..Train loss: 0.358.. Validation loss: 1.145.. Accuracy: 0.681
# Epoch: 10/18..Train loss: 0.344.. Validation loss: 1.126.. Accuracy: 0.712
# Epoch: 10/18..Train loss: 0.382.. Validation loss: 1.138.. Accuracy: 0.706
# Epoch: 10/18..Train loss: 0.290.. Validation loss: 1.184.. Accuracy: 0.704
# Epoch: 10/18..Train loss: 0.426.. Validation loss: 1.163.. Accuracy: 0.664
# Epoch: 10/18..Train loss: 0.303.. Validation loss: 1.130.. Accuracy: 0.690
# Epoch: 10/18..Train loss: 0.380.. Validation loss: 1.081.. Accuracy: 0.704
# Epoch: 10/18..Train loss: 0.461.. Validation loss: 1.235.. Accuracy: 0.692
# Epoch: 10/18..Train loss: 0.382.. Validation loss: 1.324.. Accuracy: 0.657
# Epoch: 10/18..Train loss: 0.322.. Validation loss: 1.265.. Accuracy: 0.654
# Epoch: 10/18..Train loss: 0.405.. Validation loss: 1.279.. Accuracy: 0.681
# Epoch: 10/18..Train loss: 0.362.. Validation loss: 1.090.. Accuracy: 0.713
# Epoch: 10/18..Train loss: 0.339.. Validation loss: 1.122.. Accuracy: 0.691
# Epoch: 10/18..Train loss: 0.320.. Validation loss: 1.185.. Accuracy: 0.670
# Epoch: 10/18..Train loss: 0.470.. Validation loss: 1.171.. Accuracy: 0.683
# Epoch: 11/18..Train loss: 0.347.. Validation loss: 1.223.. Accuracy: 0.676
# Epoch: 11/18..Train loss: 0.344.. Validation loss: 1.272.. Accuracy: 0.668
# Epoch: 11/18..Train loss: 0.332.. Validation loss: 1.252.. Accuracy: 0.661
# Epoch: 11/18..Train loss: 0.425.. Validation loss: 1.218.. Accuracy: 0.685
# Epoch: 11/18..Train loss: 0.328.. Validation loss: 1.144.. Accuracy: 0.690
# Epoch: 11/18..Train loss: 0.346.. Validation loss: 1.188.. Accuracy: 0.686
# Epoch: 11/18..Train loss: 0.293.. Validation loss: 1.175.. Accuracy: 0.682
# Epoch: 11/18..Train loss: 0.320.. Validation loss: 1.163.. Accuracy: 0.696
# Epoch: 11/18..Train loss: 0.346.. Validation loss: 1.208.. Accuracy: 0.679
# Epoch: 11/18..Train loss: 0.313.. Validation loss: 1.243.. Accuracy: 0.682
# Epoch: 11/18..Train loss: 0.261.. Validation loss: 1.204.. Accuracy: 0.701
# Epoch: 11/18..Train loss: 0.355.. Validation loss: 1.219.. Accuracy: 0.691
# Epoch: 11/18..Train loss: 0.359.. Validation loss: 1.252.. Accuracy: 0.670
# Epoch: 11/18..Train loss: 0.338.. Validation loss: 1.387.. Accuracy: 0.649
# Epoch: 11/18..Train loss: 0.387.. Validation loss: 1.159.. Accuracy: 0.683
# Epoch: 11/18..Train loss: 0.244.. Validation loss: 1.040.. Accuracy: 0.724
# Epoch: 11/18..Train loss: 0.378.. Validation loss: 1.202.. Accuracy: 0.691
# Epoch: 11/18..Train loss: 0.365.. Validation loss: 1.217.. Accuracy: 0.678
# Epoch: 11/18..Train loss: 0.327.. Validation loss: 1.223.. Accuracy: 0.682
# Epoch: 11/18..Train loss: 0.348.. Validation loss: 1.233.. Accuracy: 0.668
# Epoch: 12/18..Train loss: 0.361.. Validation loss: 1.169.. Accuracy: 0.694
# Epoch: 12/18..Train loss: 0.286.. Validation loss: 1.180.. Accuracy: 0.698
# Epoch: 12/18..Train loss: 0.334.. Validation loss: 1.182.. Accuracy: 0.680
# Epoch: 12/18..Train loss: 0.320.. Validation loss: 1.257.. Accuracy: 0.672
# Epoch: 12/18..Train loss: 0.287.. Validation loss: 1.122.. Accuracy: 0.724
# Epoch: 12/18..Train loss: 0.347.. Validation loss: 1.158.. Accuracy: 0.710
# Epoch: 12/18..Train loss: 0.358.. Validation loss: 1.178.. Accuracy: 0.699
# Epoch: 12/18..Train loss: 0.336.. Validation loss: 1.178.. Accuracy: 0.682
# Epoch: 12/18..Train loss: 0.275.. Validation loss: 1.161.. Accuracy: 0.675
# Epoch: 12/18..Train loss: 0.323.. Validation loss: 1.237.. Accuracy: 0.674
# Epoch: 12/18..Train loss: 0.319.. Validation loss: 1.216.. Accuracy: 0.681
# Epoch: 12/18..Train loss: 0.260.. Validation loss: 1.127.. Accuracy: 0.710
# Epoch: 12/18..Train loss: 0.250.. Validation loss: 1.112.. Accuracy: 0.726
# Epoch: 12/18..Train loss: 0.369.. Validation loss: 1.131.. Accuracy: 0.700
# Epoch: 12/18..Train loss: 0.312.. Validation loss: 1.159.. Accuracy: 0.690
# Epoch: 12/18..Train loss: 0.297.. Validation loss: 1.070.. Accuracy: 0.718
# Epoch: 12/18..Train loss: 0.309.. Validation loss: 1.156.. Accuracy: 0.705
# Epoch: 12/18..Train loss: 0.295.. Validation loss: 1.132.. Accuracy: 0.704
# Epoch: 12/18..Train loss: 0.325.. Validation loss: 1.199.. Accuracy: 0.712
# Epoch: 12/18..Train loss: 0.302.. Validation loss: 1.136.. Accuracy: 0.694
# Epoch: 12/18..Train loss: 0.324.. Validation loss: 1.114.. Accuracy: 0.708
# Epoch: 13/18..Train loss: 0.356.. Validation loss: 1.244.. Accuracy: 0.695
# Epoch: 13/18..Train loss: 0.336.. Validation loss: 1.245.. Accuracy: 0.672
# Epoch: 13/18..Train loss: 0.305.. Validation loss: 1.269.. Accuracy: 0.663
# Epoch: 13/18..Train loss: 0.317.. Validation loss: 1.192.. Accuracy: 0.694
# Epoch: 13/18..Train loss: 0.290.. Validation loss: 1.193.. Accuracy: 0.685
# Epoch: 13/18..Train loss: 0.225.. Validation loss: 1.142.. Accuracy: 0.695
# Epoch: 13/18..Train loss: 0.265.. Validation loss: 1.232.. Accuracy: 0.681
# Epoch: 13/18..Train loss: 0.307.. Validation loss: 1.273.. Accuracy: 0.673
# Epoch: 13/18..Train loss: 0.333.. Validation loss: 1.169.. Accuracy: 0.711
# Epoch: 13/18..Train loss: 0.262.. Validation loss: 1.165.. Accuracy: 0.707
# Epoch: 13/18..Train loss: 0.328.. Validation loss: 1.049.. Accuracy: 0.733
# Epoch: 13/18..Train loss: 0.316.. Validation loss: 1.157.. Accuracy: 0.701
# Epoch: 13/18..Train loss: 0.308.. Validation loss: 1.190.. Accuracy: 0.688
# Epoch: 13/18..Train loss: 0.283.. Validation loss: 1.188.. Accuracy: 0.700
# Epoch: 13/18..Train loss: 0.298.. Validation loss: 1.121.. Accuracy: 0.732
# Epoch: 13/18..Train loss: 0.324.. Validation loss: 1.116.. Accuracy: 0.721
# Epoch: 13/18..Train loss: 0.428.. Validation loss: 1.130.. Accuracy: 0.694
# Epoch: 13/18..Train loss: 0.338.. Validation loss: 1.218.. Accuracy: 0.682
# Epoch: 13/18..Train loss: 0.315.. Validation loss: 1.316.. Accuracy: 0.673
# Epoch: 13/18..Train loss: 0.224.. Validation loss: 1.200.. Accuracy: 0.685
# Epoch: 14/18..Train loss: 0.313.. Validation loss: 1.095.. Accuracy: 0.725
# Epoch: 14/18..Train loss: 0.267.. Validation loss: 1.206.. Accuracy: 0.712
# Epoch: 14/18..Train loss: 0.231.. Validation loss: 1.199.. Accuracy: 0.683
# Epoch: 14/18..Train loss: 0.301.. Validation loss: 1.144.. Accuracy: 0.722
# Epoch: 14/18..Train loss: 0.261.. Validation loss: 1.097.. Accuracy: 0.718
# Epoch: 14/18..Train loss: 0.265.. Validation loss: 1.149.. Accuracy: 0.705
# Epoch: 14/18..Train loss: 0.247.. Validation loss: 1.103.. Accuracy: 0.706
# Epoch: 14/18..Train loss: 0.326.. Validation loss: 1.224.. Accuracy: 0.683
# Epoch: 14/18..Train loss: 0.261.. Validation loss: 1.240.. Accuracy: 0.684
# Epoch: 14/18..Train loss: 0.320.. Validation loss: 1.188.. Accuracy: 0.697
# Epoch: 14/18..Train loss: 0.341.. Validation loss: 1.145.. Accuracy: 0.699
# Epoch: 14/18..Train loss: 0.257.. Validation loss: 1.299.. Accuracy: 0.652
# Epoch: 14/18..Train loss: 0.245.. Validation loss: 1.110.. Accuracy: 0.719
# Epoch: 14/18..Train loss: 0.286.. Validation loss: 1.155.. Accuracy: 0.695
# Epoch: 14/18..Train loss: 0.291.. Validation loss: 1.305.. Accuracy: 0.678
# Epoch: 14/18..Train loss: 0.245.. Validation loss: 1.206.. Accuracy: 0.694
# Epoch: 14/18..Train loss: 0.332.. Validation loss: 1.207.. Accuracy: 0.693
# Epoch: 14/18..Train loss: 0.276.. Validation loss: 1.119.. Accuracy: 0.709
# Epoch: 14/18..Train loss: 0.292.. Validation loss: 1.083.. Accuracy: 0.715
# Epoch: 14/18..Train loss: 0.263.. Validation loss: 1.139.. Accuracy: 0.697
# Epoch: 14/18..Train loss: 0.273.. Validation loss: 1.175.. Accuracy: 0.689
# Epoch: 15/18..Train loss: 0.272.. Validation loss: 1.285.. Accuracy: 0.687
# Epoch: 15/18..Train loss: 0.199.. Validation loss: 1.151.. Accuracy: 0.701
# Epoch: 15/18..Train loss: 0.236.. Validation loss: 1.103.. Accuracy: 0.713
# Epoch: 15/18..Train loss: 0.282.. Validation loss: 1.082.. Accuracy: 0.723
# Epoch: 15/18..Train loss: 0.323.. Validation loss: 1.055.. Accuracy: 0.717
# Epoch: 15/18..Train loss: 0.275.. Validation loss: 1.199.. Accuracy: 0.689
# Epoch: 15/18..Train loss: 0.254.. Validation loss: 1.143.. Accuracy: 0.714
# Epoch: 15/18..Train loss: 0.259.. Validation loss: 1.219.. Accuracy: 0.693
# Epoch: 15/18..Train loss: 0.355.. Validation loss: 1.089.. Accuracy: 0.699
# Epoch: 15/18..Train loss: 0.247.. Validation loss: 1.102.. Accuracy: 0.721
# Epoch: 15/18..Train loss: 0.197.. Validation loss: 1.167.. Accuracy: 0.691
# Epoch: 15/18..Train loss: 0.333.. Validation loss: 1.222.. Accuracy: 0.695
# Epoch: 15/18..Train loss: 0.300.. Validation loss: 1.202.. Accuracy: 0.696
# Epoch: 15/18..Train loss: 0.338.. Validation loss: 1.190.. Accuracy: 0.693
# Epoch: 15/18..Train loss: 0.241.. Validation loss: 1.159.. Accuracy: 0.691
# Epoch: 15/18..Train loss: 0.263.. Validation loss: 1.185.. Accuracy: 0.699
# Epoch: 15/18..Train loss: 0.307.. Validation loss: 1.162.. Accuracy: 0.701
# Epoch: 15/18..Train loss: 0.322.. Validation loss: 1.161.. Accuracy: 0.687
# Epoch: 15/18..Train loss: 0.300.. Validation loss: 1.255.. Accuracy: 0.692
# Epoch: 15/18..Train loss: 0.263.. Validation loss: 1.230.. Accuracy: 0.694
# Epoch: 15/18..Train loss: 0.253.. Validation loss: 1.172.. Accuracy: 0.701
# Epoch: 16/18..Train loss: 0.242.. Validation loss: 1.337.. Accuracy: 0.674
# Epoch: 16/18..Train loss: 0.255.. Validation loss: 1.077.. Accuracy: 0.733
# Epoch: 16/18..Train loss: 0.288.. Validation loss: 1.125.. Accuracy: 0.701
# Epoch: 16/18..Train loss: 0.251.. Validation loss: 1.163.. Accuracy: 0.694
# Epoch: 16/18..Train loss: 0.292.. Validation loss: 1.082.. Accuracy: 0.729
# Epoch: 16/18..Train loss: 0.262.. Validation loss: 1.121.. Accuracy: 0.701
# Epoch: 16/18..Train loss: 0.189.. Validation loss: 1.069.. Accuracy: 0.718
# Epoch: 16/18..Train loss: 0.224.. Validation loss: 1.057.. Accuracy: 0.717
# Epoch: 16/18..Train loss: 0.214.. Validation loss: 1.122.. Accuracy: 0.717
# Epoch: 16/18..Train loss: 0.213.. Validation loss: 1.123.. Accuracy: 0.718
# Epoch: 16/18..Train loss: 0.245.. Validation loss: 1.033.. Accuracy: 0.743
# Epoch: 16/18..Train loss: 0.231.. Validation loss: 1.144.. Accuracy: 0.696
# Epoch: 16/18..Train loss: 0.209.. Validation loss: 1.200.. Accuracy: 0.694
# Epoch: 16/18..Train loss: 0.218.. Validation loss: 1.163.. Accuracy: 0.703
# Epoch: 16/18..Train loss: 0.307.. Validation loss: 1.197.. Accuracy: 0.690
# Epoch: 16/18..Train loss: 0.329.. Validation loss: 1.197.. Accuracy: 0.701
# Epoch: 16/18..Train loss: 0.245.. Validation loss: 1.162.. Accuracy: 0.700
# Epoch: 16/18..Train loss: 0.338.. Validation loss: 1.315.. Accuracy: 0.687
# Epoch: 16/18..Train loss: 0.299.. Validation loss: 1.282.. Accuracy: 0.673
# Epoch: 16/18..Train loss: 0.247.. Validation loss: 1.374.. Accuracy: 0.653
# Epoch: 17/18..Train loss: 0.271.. Validation loss: 1.132.. Accuracy: 0.707
# Epoch: 17/18..Train loss: 0.268.. Validation loss: 1.171.. Accuracy: 0.692
# Epoch: 17/18..Train loss: 0.252.. Validation loss: 1.294.. Accuracy: 0.669
# Epoch: 17/18..Train loss: 0.198.. Validation loss: 1.167.. Accuracy: 0.699
# Epoch: 17/18..Train loss: 0.215.. Validation loss: 1.225.. Accuracy: 0.682
# Epoch: 17/18..Train loss: 0.246.. Validation loss: 1.229.. Accuracy: 0.709
# Epoch: 17/18..Train loss: 0.252.. Validation loss: 1.095.. Accuracy: 0.726
# Epoch: 17/18..Train loss: 0.208.. Validation loss: 1.267.. Accuracy: 0.683
# Epoch: 17/18..Train loss: 0.237.. Validation loss: 1.245.. Accuracy: 0.696
# Epoch: 17/18..Train loss: 0.256.. Validation loss: 1.090.. Accuracy: 0.730
# Epoch: 17/18..Train loss: 0.161.. Validation loss: 1.053.. Accuracy: 0.720
# Epoch: 17/18..Train loss: 0.257.. Validation loss: 1.086.. Accuracy: 0.728
# Epoch: 17/18..Train loss: 0.226.. Validation loss: 1.078.. Accuracy: 0.722
# Epoch: 17/18..Train loss: 0.229.. Validation loss: 1.218.. Accuracy: 0.690
# Epoch: 17/18..Train loss: 0.232.. Validation loss: 1.105.. Accuracy: 0.712
# Epoch: 17/18..Train loss: 0.269.. Validation loss: 1.173.. Accuracy: 0.700
# Epoch: 17/18..Train loss: 0.211.. Validation loss: 1.159.. Accuracy: 0.714
# Epoch: 17/18..Train loss: 0.265.. Validation loss: 1.222.. Accuracy: 0.692
# Epoch: 17/18..Train loss: 0.224.. Validation loss: 1.176.. Accuracy: 0.696
# Epoch: 17/18..Train loss: 0.308.. Validation loss: 1.191.. Accuracy: 0.681
# Epoch: 17/18..Train loss: 0.250.. Validation loss: 1.236.. Accuracy: 0.672
# Epoch: 18/18..Train loss: 0.207.. Validation loss: 1.139.. Accuracy: 0.709
# Epoch: 18/18..Train loss: 0.248.. Validation loss: 1.063.. Accuracy: 0.731
# Epoch: 18/18..Train loss: 0.239.. Validation loss: 1.157.. Accuracy: 0.699
# Epoch: 18/18..Train loss: 0.285.. Validation loss: 1.241.. Accuracy: 0.674
# Epoch: 18/18..Train loss: 0.254.. Validation loss: 1.110.. Accuracy: 0.701
# Epoch: 18/18..Train loss: 0.268.. Validation loss: 1.175.. Accuracy: 0.708
# Epoch: 18/18..Train loss: 0.220.. Validation loss: 1.155.. Accuracy: 0.705
# Epoch: 18/18..Train loss: 0.244.. Validation loss: 1.113.. Accuracy: 0.714
# Epoch: 18/18..Train loss: 0.231.. Validation loss: 1.116.. Accuracy: 0.709
# Epoch: 18/18..Train loss: 0.262.. Validation loss: 1.154.. Accuracy: 0.704
# Epoch: 18/18..Train loss: 0.228.. Validation loss: 1.239.. Accuracy: 0.681
# Epoch: 18/18..Train loss: 0.252.. Validation loss: 1.121.. Accuracy: 0.715
# Epoch: 18/18..Train loss: 0.228.. Validation loss: 1.140.. Accuracy: 0.693
# Epoch: 18/18..Train loss: 0.238.. Validation loss: 1.152.. Accuracy: 0.713
# Epoch: 18/18..Train loss: 0.284.. Validation loss: 1.229.. Accuracy: 0.691
# Epoch: 18/18..Train loss: 0.230.. Validation loss: 1.084.. Accuracy: 0.736
# Epoch: 18/18..Train loss: 0.186.. Validation loss: 1.180.. Accuracy: 0.699
# Epoch: 18/18..Train loss: 0.246.. Validation loss: 1.175.. Accuracy: 0.696
# Epoch: 18/18..Train loss: 0.231.. Validation loss: 1.215.. Accuracy: 0.694
# Epoch: 18/18..Train loss: 0.219.. Validation loss: 1.204.. Accuracy: 0.700

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set

epochs = 1
steps = 0
running_loss = 0
print_every = 5

for e in range(epochs):
    for images, labels in trainloader:
        steps += 1
        
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        log_ps = model.forward(images)
        loss = criterion(log_ps, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        if steps % print_every == 0:
            test_loss = 0 ## test loss
            accuracy = 0
            model.eval()

            with torch.no_grad():
                for images, labels in testloader:
                    images, labels = images.to(device), labels.to(device)

                    log_ps = model.forward(images)
                    loss = criterion(log_ps, labels)

                    test_loss += loss.item()

                    ## calculate accuracy
                    ps = torch.exp(log_ps)
                    top_p, top_class = ps.topk(1, dim = 1)
                    equals = (top_class == labels.view(*top_class.shape))

                    accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
                    #print(test_loss)
 
            print(f"Epoch: {e+1}/{epochs}..",
                  f"Train loss: {running_loss/print_every:.3f}.. ",
                  f"Test loss: {test_loss/len(testloader):.3f}.. ",
                  f"Accuracy: {accuracy/len(testloader):.3f}")
            running_loss = 0
            model.train()
# Out:
# Epoch: 1/1.. Train loss: 0.222..  Test loss: 1.266..  Accuracy: 0.692
# Epoch: 1/1.. Train loss: 0.250..  Test loss: 1.246..  Accuracy: 0.681
# Epoch: 1/1.. Train loss: 0.228..  Test loss: 1.278..  Accuracy: 0.671
# Epoch: 1/1.. Train loss: 0.185..  Test loss: 1.083..  Accuracy: 0.724
# Epoch: 1/1.. Train loss: 0.220..  Test loss: 1.251..  Accuracy: 0.680
# Epoch: 1/1.. Train loss: 0.201..  Test loss: 1.232..  Accuracy: 0.702
# Epoch: 1/1.. Train loss: 0.166..  Test loss: 1.259..  Accuracy: 0.673
# Epoch: 1/1.. Train loss: 0.264..  Test loss: 1.241..  Accuracy: 0.691
# Epoch: 1/1.. Train loss: 0.281..  Test loss: 1.196..  Accuracy: 0.730
# Epoch: 1/1.. Train loss: 0.191..  Test loss: 1.259..  Accuracy: 0.699
# Epoch: 1/1.. Train loss: 0.338..  Test loss: 1.347..  Accuracy: 0.668
# Epoch: 1/1.. Train loss: 0.258..  Test loss: 1.231..  Accuracy: 0.700
# Epoch: 1/1.. Train loss: 0.279..  Test loss: 1.267..  Accuracy: 0.683
# Epoch: 1/1.. Train loss: 0.208..  Test loss: 1.340..  Accuracy: 0.680
# Epoch: 1/1.. Train loss: 0.210..  Test loss: 1.367..  Accuracy: 0.682
# Epoch: 1/1.. Train loss: 0.218..  Test loss: 1.197..  Accuracy: 0.708
# Epoch: 1/1.. Train loss: 0.211..  Test loss: 1.285..  Accuracy: 0.678
# Epoch: 1/1.. Train loss: 0.256..  Test loss: 1.226..  Accuracy: 0.690
# Epoch: 1/1.. Train loss: 0.255..  Test loss: 1.230..  Accuracy: 0.692
# Epoch: 1/1.. Train loss: 0.180..  Test loss: 1.197..  Accuracy: 0.695

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = train_data.class_to_idx

def save_checkpoint(file_path):
    checkpoint = {'epochs': 18,
                  'arch': 'densenet121',
                  'input_size': 1024,
                  'output_size': 102,
                  'learning_rate': 0.001,
                  'classifier': model.classifier,
                 'state_dict': model.state_dict(),
                 'class_to_idx': model.class_to_idx,
                 'optimizer': optimizer.state_dict
                 }
    torch.save(checkpoint, file_path)
    print('The model is saved in', file_path)

save_checkpoint('checkpoint.pth')
# Out:
# The model is saved in checkpoint.pth

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def load_checkpoint(file_path):
    
    checkpoint = torch.load(file_path)
    
    arch = checkpoint['arch']
    input_size = checkpoint['input_size']
    output_size = checkpoint['output_size']
    lr = checkpoint['learning_rate']
    epochs = checkpoint['epochs']
    
    for param in model.parameters():
        param.requires_grad = False  
    
    model.classifier = checkpoint['classifier']
    model.class_to_idx = checkpoint['class_to_idx']
    model.optimizer = checkpoint['optimizer'] 
    
    model.load_state_dict(checkpoint['state_dict'])
    
    return model

# %%
model2 = load_checkpoint('checkpoint.pth')
print(model2)
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(96, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(160, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(224, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(224, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(288, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(320, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(352, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(416, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(416, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(448, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(480, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace)
#       (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(544, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(544, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(576, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(608, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(608, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(640, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(672, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(704, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(704, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(736, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(736, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(800, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(800, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(832, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(832, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(864, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(896, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(928, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(928, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(960, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(992, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace)
#         (conv1): Conv2d(992, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace)
#         (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=1024, out_features=500, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.3)
#     (3): Linear(in_features=500, out_features=102, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch mode
    img = Image.open(image)
    ## resize image
    im_thn = img.resize((256, 256))
    
    width_rs, height_rs = im_thn.size ## width and height of resize
    
    ## crop out the center 224x224 of the image
    width_cr, height_cr = (224, 224) ## width and height of cropped image
    
    left = (width_rs - width_cr) / 2
    right = (left + width_cr)
    
    top = (height_rs - height_cr) / 2 
    bottom = (top + height_cr)
    
    ## crop image
    im_cr = im_thn.crop((left, top, right, bottom))
    
    ## get colors
    np_image = np.array(im_cr)/255 ## convert to floats between 0 and 1
    
    means = np.array([0.485, 0.456, 0.406])
    stds = np.array([0.229, 0.224, 0.225])
    
    norm_img = (np_image - means)/stds ## normalize images
    
    img_reorder = norm_img.transpose((2, 0, 1))
    img_final = torch.from_numpy(img_reorder) ## convert to tensor
    return img_final

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
img = process_image(test_dir + '/15/image_06374.jpg')
imshow(img)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    ## input image
    flower_in = process_image(image_path)
    
    ## convert to cuda
    images = flower_in.type(torch.cuda.FloatTensor) 
    
    ## unsqueeze input images
    images = images.unsqueeze(0)
    
    ## run model with image
    model.eval()
    with torch.no_grad():

        log_ps = model.forward(images)
        ps = torch.exp(log_ps)
        top_p, top_classes = ps.topk(topk, dim = 1)
        
        ## convert tensors to lists
        top_p = top_p.tolist()[0] 
        top_classes = top_classes.tolist()[0]
        
        ## list of labels turned to strings
        class_list = list(map(str, top_classes))
        
        ## classes converted to flower names
        top_labels = [cat_to_name[i] for i in class_list]
        

    return top_p, top_classes, top_labels

# %%
probs, classes, top_labels = predict(test_dir + '/15/image_06374.jpg', model= model2)
print(probs)
print(classes)
print(top_labels)
# Out:
# [0.535749077796936, 0.14466699957847595, 0.08080961555242538, 0.05876142159104347, 0.04182250052690506]
# [16, 80, 64, 95, 75]
# ['globe-flower', 'anthurium', 'silverbush', 'bougainvillea', 'thorn apple']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import torch.nn.functional as F

def sanity_check(img_path, model):
    

    
    img = process_image(img_path)
    show_img = imshow(img)
    
    fig, ax = plt.subplots()
    
    probs, classes, labels = predict(img_path, model, topk = 5)
    
    ax.barh(labels, probs)
    ax.set_yticklabels(labels)
    ax.set_ylabel('Flower Species')
    ax.set_xlabel('Probability')
    ax.set_title('Probability of Flower Names')
    plt.show()


sanity_check((test_dir + '/1/image_06754.jpg'), model= model2)
